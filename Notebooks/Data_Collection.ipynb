# %% [markdown]
# DATA COLLECTION

# %%
import pandas as pd
import numpy as np

# %%
df_IDS_ALLCountries_Data = pd.read_csv('IDS_ALLCountries_Data.csv', encoding='latin1')

# %%
df_IDS_ALLCountries_Data.shape
# Out:
# (62983, 39)

# %%
df_IDS_ALLCountries_Data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Counterpart-Area Name',
#        'Counterpart-Area Code', 'Series Name', 'Series Code', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028',
#        '2029', '2030', '2031', '2032'],
#       dtype='object')

# %%
df_IDS_ALLCountries_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62983 entries, 0 to 62982
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country Name           62980 non-null  object
#  1   Country Code           62978 non-null  object
#  2   Counterpart-Area Name  62978 non-null  object
#  3   Counterpart-Area Code  62978 non-null  object
#  4   Series Name            62978 non-null  object
#  5   Series Code            62978 non-null  object
#  6   2000                   49490 non-null  float64
#  7   2001                   49434 non-null  float64
#  8   2002                   49262 non-null  float64
#  9   2003                   49001 non-null  float64
#  10  2004                   49195 non-null  float64
#  11  2005                   49137 non-null  float64
#  12  2006                   49394 non-null  float64
#  13  2007                   49645 non-null  float64
# ...

# %%
df_IDS_ALLCountries_Data.head()
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan   AFG                        World                   WLD
# 1  Afghanistan   AFG                        World                   WLD
# 2  Afghanistan   AFG                        World                   WLD
# 3  Afghanistan   AFG                        World                   WLD
# 4  Afghanistan   AFG                        World                   WLD
#
#                                          Series Name  Series Code  2000  2001  \
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 1  Average grace period on new external debt comm...  DT.GPA.OFFT   NaN   NaN
# 2  Average grace period on new external debt comm...  DT.GPA.PRVT   NaN   NaN
# 3  Average grant element on new external debt com...  DT.GRE.DPPG   NaN   NaN
# 4  Average grant element on new external debt com...  DT.GRE.OFFT   NaN   NaN
#
# ...

# %% [markdown]
# IDS_ALLCountries_Data - Observations
#
# Contains 62,983 rows and 39 columns
# Contains country-level debt indicators
# Year columns range from 2000 to 2032
# Contains Country Name, Country Code, Counterpart-Area Name, Counterpart-Area code, Series Name, Series Code
# Contains missing values in year columns

# %%
df_country_series = pd.read_csv('Country-Series - Metadata.csv', encoding='latin1')

# %%
df_country_series.shape
# Out:
# (375, 4)

# %%
df_country_series.columns
# Out:
# Index(['Type', 'Country Code', 'Series Code', 'Description'], dtype='object')

# %%
df_country_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Type          375 non-null    object
#  1   Country Code  375 non-null    object
#  2   Series Code   375 non-null    object
#  3   Description   375 non-null    object
# dtypes: object(4)
# memory usage: 11.8+ KB

# %%
df_country_series.head()
# Out:
#              Type       Country Code  \
# 0  Country-Series  Afghanistan (AFG)
# 1  Country-Series  Afghanistan (AFG)
# 2  Country-Series  Afghanistan (AFG)
# 3  Country-Series       Angola (AGO)
# 4  Country-Series       Angola (AGO)
#
#                                          Series Code  \
# 0  Foreign direct investment, net inflows in repo...
# 1                    Population, total (SP.POP.TOTL)
# 2  External debt stocks, total (DOD, current US$)...
# 3  External debt stocks, total (DOD, current US$)...
# 4                    Population, total (SP.POP.TOTL)
#
#                                          Description
# 0  Data on Foreign Direct Investment are based on...
# 1  Data source: United Nations World Population P...
# 2  Long-term public and publicly guaranteed, long...
# 3  Long-term public and publicly guaranteed debt ...
# 4  Data source: United Nations World Population P...

# %% [markdown]
# Country series
#
# Contains 374 rows and 4 columns
#
# Contains country code, series code, description

# %%
df_IDS_CountryMetaData = pd.read_csv('IDS_CountryMetaData.csv', encoding='latin1')

# %%
df_IDS_CountryMetaData.shape
# Out:
# (134, 30)

# %%
df_IDS_CountryMetaData.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'PPP survey years', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', '2-alpha code', 'WB-2 code',
#        'Table Name', 'Short Name'],
#       dtype='object')

# %%
df_IDS_CountryMetaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 30 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Code                                               134 non-null    object
#  1   Long Name                                          134 non-null    object
#  2   Income Group                                       119 non-null    object
#  3   Region                                             120 non-null    object
#  4   Lending category                                   120 non-null    object
#  5   Other groups                                       40 non-null     object
#  6   Currency Unit                                      120 non-null    object
#  7   Latest population census                           118 non-null    object
#  8   Latest household survey                            120 non-null    object
# ...

# %%
df_IDS_CountryMetaData.head()
# Out:
#   Code                                Long Name         Income Group  \
# 0  AFG             Islamic State of Afghanistan           Low income
# 1  ALB                      Republic of Albania  Upper middle income
# 2  DZA  People's Democratic Republic of Algeria  Upper middle income
# 3  AGO              People's Republic of Angola  Lower middle income
# 4  ARG                       Argentine Republic  Upper middle income
#
#                        Region Lending category Other groups   Currency Unit  \
# 0  Middle East & North Africa              IDA         HIPC  Afghan afghani
# 1       Europe & Central Asia             IBRD          NaN    Albanian lek
# 2  Middle East & North Africa             IBRD          NaN  Algerian dinar
# 3          Sub-Saharan Africa             IBRD          NaN  Angolan kwanza
# 4   Latin America & Caribbean             IBRD          NaN  Argentine peso
#
#   Latest population census                      Latest household survey  \
# ...

# %% [markdown]
# IDS_CountryMetaData
#
# Contains 134 rows and 30 columns
#
# Contains Country Metadata

# %%
df_IDS_FootNoteMetaData = pd.read_csv('IDS_FootNoteMetaData.csv', encoding='latin1')

# %%
df_IDS_FootNoteMetaData.shape
# Out:
# (2673, 5)

# %%
df_IDS_FootNoteMetaData.columns
# Out:
# Index(['Type', 'Country Code', 'Series Code', 'Time Code', 'Description'], dtype='object')

# %%
df_IDS_FootNoteMetaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2673 entries, 0 to 2672
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Type          2673 non-null   object
#  1   Country Code  2673 non-null   object
#  2   Series Code   2673 non-null   object
#  3   Time Code     2673 non-null   object
#  4   Description   2673 non-null   object
# dtypes: object(5)
# memory usage: 104.5+ KB

# %%
df_IDS_FootNoteMetaData.head()
# Out:
#        Type       Country Code  \
# 0  FootNote  Afghanistan (AFG)
# 1  FootNote  Afghanistan (AFG)
# 2  FootNote  Afghanistan (AFG)
# 3  FootNote  Afghanistan (AFG)
# 4  FootNote  Afghanistan (AFG)
#
#                                          Series Code      Time Code  \
# 0  Personal transfers and compensation of employe...  2024 (YR2024)
# 1  Personal transfers and compensation of employe...  2023 (YR2023)
# 2  Personal transfers and compensation of employe...  2021 (YR2021)
# 3  Personal transfers and compensation of employe...  2022 (YR2022)
# 4  Foreign direct investment, net inflows in repo...  2021 (YR2021)
#
#                                          Description
# 0  Data on Personal Transfers and Compensation of...
# 1  Source: United Nations Conference on Trade and...
# 2  Source: United Nations Conference on Trade and...
# 3  Source: United Nations Conference on Trade and...
# 4  Source: United Nations Conference on Trade and...

# %% [markdown]
# IDS_FootNoteMetaData
#
# Contains 2673 rows and 5 columns

# %%
df_IDS_SeriesMetaData = pd.read_csv('IDS_SeriesMetaData.csv',encoding='latin1')

# %%
df_IDS_SeriesMetaData.shape
# Out:
# (574, 12)

# %%
df_IDS_SeriesMetaData.columns
# Out:
# Index(['Code', 'License Type', 'Indicator Name', 'Short definition',
#        'Long definition', 'Source', 'Topic', 'Dataset', 'Periodicity',
#        'Aggregation method', 'Limitations and exceptions', 'General comments'],
#       dtype='object')

# %%
df_IDS_SeriesMetaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Code                        574 non-null    object
#  1   License Type                2 non-null      object
#  2   Indicator Name              574 non-null    object
#  3   Short definition            572 non-null    object
#  4   Long definition             574 non-null    object
#  5   Source                      574 non-null    object
#  6   Topic                       574 non-null    object
#  7   Dataset                     573 non-null    object
#  8   Periodicity                 574 non-null    object
#  9   Aggregation method          574 non-null    object
#  10  Limitations and exceptions  1 non-null      object
#  11  General comments            8 non-null      object
# dtypes: object(12)
# memory usage: 53.9+ KB

# %%
df_IDS_SeriesMetaData.head()
# Out:
#           Code License Type  \
# 0  DT.GPA.DPPG          NaN
# 1  DT.GPA.OFFT          NaN
# 2  DT.GPA.PRVT          NaN
# 3  DT.GRE.DPPG          NaN
# 4  DT.GRE.OFFT          NaN
#
#                                       Indicator Name  \
# 0  Average grace period on new external debt comm...
# 1  Average grace period on new external debt comm...
# 2  Average grace period on new external debt comm...
# 3  Average grant element on new external debt com...
# 4  Average grant element on new external debt com...
#
#                                     Short definition  \
# 0  Grace period is the period from the date of si...
# 1  Grace period is the period from the date of si...
# 2  Grace period is the period from the date of si...
# 3  The grant element of a loan is the grant equiv...
# 4  The grant element of a loan is the grant equiv...
#
#                                      Long definition  \
# 0  Grace period is the period from the date of si...
# ...

# %% [markdown]
# IDS_SeriesMetaData
#
# Contains 574 rows and 12 columns
